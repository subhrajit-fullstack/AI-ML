# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Auto MPG:-

# %%
auto = pd.read_csv(r"/Users/nexusop03/Downloads/auto+mpg/auto-mpg.data",header = None,delim_whitespace=True)
auto
# Out:
#         0  1      2      3       4     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2                  vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1              dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1                ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# <pre>Delimiter :- Column ko separate karna
#
# delimiter tabhi kaa karta hai jab column mein space hota hai
#
# <i>"pd.read_csv"</i> tabhi use karna hai jab humare pass <i>".data / .csv"</i> file ho aur ye dataset ko read karne ke liye use hota hai
#
# pd.read_excel(...xlsx)
# pd.read_json(...json)
# </pre>

# %% [markdown]
# # Rename the column:-

# %%
auto.columns = ['mpg', 'cylinders', 'displacement', 'Horsepower','weight', 'acceleration','model year','origin', 'car name']
auto
# Out:
#       mpg  cylinders  displacement Horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
auto.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# Horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# Horsepower       object
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
for i in auto.columns:
    print(i ,':','\n', auto[i].unique(),'\n')
# Out:
# mpg :
#  [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
#
# cylinders :
#  [8 4 6 3 5]
#
# displacement :
#  [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
for i in auto.columns:
    print(i,';',sum(auto[i]=='?'))
# Out:
# mpg ; 0
# cylinders ; 0
# displacement ; 0
# Horsepower ; 6
# weight ; 0
# acceleration ; 0
# model year ; 0
# origin ; 0
# car name ; 0

# %%
auto['Horsepower'] = auto['Horsepower'].replace('?', np.nan)
for i in auto.columns:
    print(i,';',sum(auto[i]=='?'))
# Out:
# mpg ; 0
# cylinders ; 0
# displacement ; 0
# Horsepower ; 0
# weight ; 0
# acceleration ; 0
# model year ; 0
# origin ; 0
# car name ; 0

# %%
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# Horsepower       object
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
auto.Horsepower = auto.Horsepower.astype(float)
auto
# Out:
#       mpg  cylinders  displacement  Horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
d=auto.describe(include = 'all')
d
# Out:
#                mpg   cylinders  displacement  Horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model year      origin    car name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
auto['Horsepower'] = auto['Horsepower'].fillna(auto['Horsepower'][4])
auto
# Out:
#       mpg  cylinders  displacement  Horsepower  weight  acceleration  \
# 0    18.0          8         307.0  104.469388  3504.0          12.0
# 1    15.0          8         350.0  104.469388  3693.0          11.5
# 2    18.0          8         318.0  104.469388  3436.0          11.0
# 3    16.0          8         304.0  104.469388  3433.0          12.0
# 4    17.0          8         302.0  104.469388  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0  104.469388  2790.0          15.6
# 394  44.0          4          97.0  104.469388  2130.0          24.6
# 395  32.0          4         135.0  104.469388  2295.0          11.6
# 396  28.0          4         120.0  104.469388  2625.0          18.6
# 397  31.0          4         119.0  104.469388  2720.0          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# # Process Of Data Cleaning:-
# <pre>1.Reading the dataset
#      2.rename the column name if required
#      3.Check missing values or NULL values ('isnull().sum()')
#      4.Check Datatype
#      5.Check unique values
#      6.Replace the Missing Value
# </pre>

# %% [markdown]
# # MATPLOTLIB:-
