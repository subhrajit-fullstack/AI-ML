# %% [markdown]
# # Machine Learning Procedure:-
# <pre><i>
#     1.Reading the Dataset<br>
#     2.Data cleaning<br>
#     3.Data Analysis<br>
#     4.Data Encoding<br>
#     5.I/P & O/P Creation<br>
#     6.train_test_split<br>
#     7.Standard scalar transform / Data Standardization<br>
#     8.Machine Learning Algorithm<br>
#     9.Prediction<br>
#     10.Accuracu
# </i>
# </pre>
