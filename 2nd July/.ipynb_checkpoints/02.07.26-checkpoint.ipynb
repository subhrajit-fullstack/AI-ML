# %% [markdown]
# # BASIC PYTHON
# # Python is case sensitive.

# %% [markdown]
# # COMMENT LINE

# %% [raw]
# COMMENT LINE:- Non-executable piece of code

# %% [markdown]
# # Key Words:-

# %%
# Key Words:- 
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# # IDENTIFIER

# %% [raw]
# It is a name of a function and class

# %% [markdown]
# # VARIABLE

# %% [raw]
# VARIABLE NAMING RULE:-
# 1)We can't use keywords as a variable name.
# 2)We can't use digits or numbers in the start of a variable name.
# 3)We can't use special symbols in between in a variable name except '_'.
# 4)We can't use space in between a variable name instead we can use '_'.

# %%
a = 2.5

# %%
else = 10
# Out:
#   Cell In[5], line 1
#     else = 10
#     ^
# SyntaxError: invalid syntax

# %%
12var = 23
# Out:
#   Cell In[6], line 1
#     12var = 23
#      ^
# SyntaxError: invalid decimal literal

# %%
var!23 = 126
# Out:
#   Cell In[7], line 1
#     var!23 = 126
#        ^
# SyntaxError: invalid syntax

# %%
first var = 12
# Out:
#   Cell In[8], line 1
#     first var = 12
#           ^
# SyntaxError: invalid syntax

# %%
first_var = 12

# %%
first_var
# Out:
# 12

# %% [markdown]
# # DATATYPES:-

# %%
a = 12
type(a)
# Out:
# int

# %%
a = 27.5
type(a)
# Out:
# float

# %%
a = True 
type(a)
# Out:
# bool

# %% [markdown]
# # COMPLEX :-

# %%
c = 6 + 2i
type(c)
# Out:
#   Cell In[14], line 1
#     c = 6 + 2i
#             ^
# SyntaxError: invalid decimal literal

# %%
c = 6 + 2j
type(c)
# Out:
# complex

# %% [markdown]
# # SEQUENTIAL:-

# %% [markdown]
# ## 1)STRING:-

# %%
# String:-
# It is a sequence of characters store with in single quotation or double quotation.

# %%
S = "hello"
S
# Out:
# 'hello'

# %%
type(S)
# Out:
# str

# %%
# Multi Line String:-
# for this we have to use triple single quotation (''' ''')or triple double quotation(""" """).

# %%
s1 = """ Hello Everyone
 welcome to CTTC"""
print(s1)
# Out:
#  Hello Everyone
#  welcome to CTTC

# %%
type(s1)
# Out:
# str
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# ## 2)LIST:-

# %% [raw]
# It is a sequence of ellement separated by commas and it is ordered and mutable and
# it can supppose homogeneous or herterogeneous datatypes.

# %%
# List
l = [34,29,12,56,883,25,34.2,'color']
print(l)
# Out:
# [34, 29, 12, 56, 883, 25]

# %%
type(l)
# Out:
# list

# %% [markdown]
# ## 3)TUPLE:-

# %% [raw]
# It is a sequence of items stored in a parenthesis and separated with commas.It is ordered and immutable.
# It can supporthomogeneous and heterogeneous datatype.

# %%
# tuple
t = (34,29,12,56,883,25,34.2,'color')
t
# Out:
# (34, 29, 12, 56, 883, 25, 34.2, 'color')

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# ## 4)SET:-

# %% [raw]
# It is a unique collecton of data or unique collection of elements stored inside a curly brackets and seprated with comma.
# It is unordered and mutable.It can support homo-geneous and hetero-geneous datatypes.

# %%
# Set:-
se = {12,12,34.5,43,'Cat',23,8,11,34,67,12,True}
se
# Out:
# {11, 12, 23, 34, 34.5, 43, 67, 8, 'Cat', True}

# %%
type(se)
# Out:
# set

# %% [markdown]
# ## 5)DICTIONARY:-

# %% [raw]
# It is a collection of paired elements stored inside a curly bracket and separated with comma.
# It is ordered and mutable.It can support homo-geneous and hetero-geneous datatypes.
# Each paired element consist of one key and value separated with columns and a dictionary must have a
# unique key.

# %%
#Dictionary:-
d = { 'Name':'Hari',
      'Roll':'23',
      'Age':21,
}
d
# Out:
# {'Name': 'Hari', 'Roll': '23', 'Age': 21}

# %%
type(d)
# Out:
# dict

# %%
#Dictionary:-
d = { 'Name':'Hari',
      'Roll':'23',
      'Age':21,
      'Name':'Ram',
}
d
# Out:
# {'Name': 'Ram', 'Roll': '23', 'Age': 21}

# %% [markdown]
# # Indexing:-

# %% [raw]
# Syntax:
# Var [index_position]

# %%
S = 'Apple'
S
# Out:
# 'Apple'

# %%
S[2]
# Out:
# 'p'

# %%
S[-2]
# Out:
# 'l'

# %%
S[-2],S[-3]
# Out:
# ('l', 'p')

# %% [markdown]
# # Slicing:-

# %% [raw]
# Syntax:-
# var[start:stop+1:step]
# Backward Slicing :-
# var[start:stop-1:step(-ve)]

# %%
S[2:4:1]
# Out:
# 'pl'

# %%
S[-3:-1:1]
# Out:
# 'pl'

# %%
S[-3:4]
# Out:
# 'pl'

# %%
S[:3]
# Out:
# 'App'

# %%
S[:5:2]
# Out:
# 'Ape'

# %%
S[-1:-6:-2]
# Out:
# 'epA'
