# %% [markdown]
# # Seaborn:-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv(r"/Users/nexusop03/Downloads/iris/iris.data",header = None)
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
for i in

# %%
iris.columns=['sepal_length','sepal_width','petal_length','petal_width','class']
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Distribution Plot:-

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
# Distribution Plot
sns.distplot(iris.sepal_length)
plt.show()

# %%
iris.sepal_width.value_counts()
# Out:
# sepal_width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: count, dtype: int64

# %%
# Histplot
sns.histplot(iris.sepal_width)
plt.show()

# %%
sns.displot(iris.sepal_width)
plt.show()

# %%
sns.kdeplot(iris.petal_width)
plt.show()

# %%
sns.kdeplot(iris.petal_length, fill = True, color ='c',hatch ='\/|\/',edgecolor = 'r')
plt.show()

# %%
sns.histplot(iris.petal_width,color ='b', fill= False, hatch = '//||\\')
plt.show()

# %%
sns.distplot(iris.sepal_width[iris['class'] == 'Iris-setosa'])
sns.distplot(iris.sepal_width[iris['class'] == 'Iris-versicolor'])
sns.distplot(iris.sepal_width[iris['class'] == 'Iris-virginica'])
plt.show()

# %%
sns.displot(iris.sepal_width[iris['class'] == 'Iris-setosa'])
sns.displot(iris.sepal_width[iris['class'] == 'Iris-versicolor'])
sns.displot(iris.sepal_width[iris['class'] == 'Iris-virginica'])
plt.show()

# %%
sns.histplot(iris.sepal_width[iris['class'] == 'Iris-setosa'])
sns.histplot(iris.sepal_width[iris['class'] == 'Iris-versicolor'])
sns.histplot(iris.sepal_width[iris['class'] == 'Iris-virginica'])
plt.show()

# %%
sns.kdeplot(iris.sepal_width[iris['class'] == 'Iris-setosa'])
sns.kdeplot(iris.sepal_width[iris['class'] == 'Iris-versicolor'])
sns.kdeplot(iris.sepal_width[iris['class'] == 'Iris-virginica'])
plt.show()

# %%
sns.boxplot(iris.sepal_width)
plt.show()

# %%
sns.boxplot(x = iris['class'],y = iris.sepal_length)
plt.show()

# %%
sns.boxplot(x = iris['class'],y = iris.sepal_length,hue = iris['class'])
plt.show()

# %%
#Boxen plot
sns.boxenplot(x = iris['class'],y = iris.sepal_length,palette = 'bright')
plt.show()

# %%
sns.boxenplot(iris.sepal_length)
plt.show()

# %%
np.percentile(iris.sepal_length,6.25)
# Out:
# 4.7

# %%
sns.violinplot(y = iris.sepal_length,x = iris ['class'],palette='crest')
plt.show()

# %%
sns.stripplot(y = iris.sepal_length,x = iris ['class'],palette='dark')
plt.show()

# %%
sns.swarmplot(y = iris.sepal_length,x = iris ['class'],palette='bright')
plt.show()

# %%
sns.barplot(y = iris.sepal_length,x = iris ['class'],palette='dark')
plt.show()

# %%
sns.pointplot(y = iris.sepal_length,x = iris ['class'],palette='bright')
plt.show()
# jahan pe maximum data hota hai wahan pe centroid pe point create karta hai

# %%
sns.scatterplot(y = iris.sepal_width,x = iris.sepal_length,hue =iris['class'])
plt.show()
